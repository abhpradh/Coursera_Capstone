# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#get_ipython().system(u"conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab")
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#get_ipython().system(u"conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab")
import folium # map rendering library

print('Libraries imported Successfully.')
# Out:
# Libraries imported Successfully.

# %%
sac_data = pd.read_csv(r"C:\Users\20581888\Desktop\projects\Coursera_Capstone\Sacramento Neighbourhood.csv")
sac_data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Downtown</td>
#       <td>38.581776</td>
#       <td>-121.511825</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Old Sacramento</td>
#       <td>38.577305</td>
#       <td>-121.517995</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>East Sacramento</td>
#       <td>38.567844</td>
#       <td>-121.481205</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Midtwon</td>
#       <td>38.572511</td>
#       <td>-121.494525</td>
#     </tr>
# ...

# %%
print('The dataframe has {} Neighbourhoods.'.format(len(sac_data['Neighbourhood']),sac_data.shape[0]))
# Out:
# The dataframe has 50 Neighbourhoods.

# %%
address = 'Sacramento, CA'

geolocator = Nominatim()
sac_location = geolocator.geocode(address)
sac_latitude = sac_location.latitude
sac_longitude = sac_location.longitude
print('The geograpical coordinate of Sacramento are {}, {}.'.format(sac_latitude, sac_longitude))
# Out:
# C:\Users\20581888\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   This is separate from the ipykernel package so we can avoid doing imports until
# The geograpical coordinate of Sacramento are 38.5815719, -121.4943996.

# %%
# create map of Sacramento using latitude and longitude values
map_sac = folium.Map(location=[sac_latitude, sac_longitude], zoom_start=10)

# %%
# add markers to map
for lat, lng, neighbourhood in zip(sac_data['Latitude'], sac_data['Longitude'], sac_data['Neighbourhood']):
    label = '{}'.format(neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=1).add_to(map_sac)
    
map_sac
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Define Foursquare Credentials and Version
CLIENT_ID = '5IGRTVSEE1JRUGYEX24C0NDOMWCBA25EVXUITRZ0D3FCLTQO' 
CLIENT_SECRET = 'VHUHGVBSYGCV1BBUPVRNYSORFNANGTLVBQQ44TSN35IJNFNT' 
VERSION = '20190218' 
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5IGRTVSEE1JRUGYEX24C0NDOMWCBA25EVXUITRZ0D3FCLTQO
# CLIENT_SECRET:VHUHGVBSYGCV1BBUPVRNYSORFNANGTLVBQQ44TSN35IJNFNT

# %%
neighbourhood_latitude = sac_data.loc[0, 'Latitude'] # neighborhood latitude value
neighbourhood_longitude = sac_data.loc[0, 'Longitude'] # neighborhood longitude value

neighbourhood_name = sac_data.loc[0, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of Downtown are 38.581776399999995, -121.51182460000001.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5IGRTVSEE1JRUGYEX24C0NDOMWCBA25EVXUITRZ0D3FCLTQO&client_secret=VHUHGVBSYGCV1BBUPVRNYSORFNANGTLVBQQ44TSN35IJNFNT&v=20190218&ll=38.581776399999995,-121.51182460000001&radius=500&limit=100'

# %%
results = requests.get(url).json()
#results

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
sac_venues = getNearbyVenues(names=sac_data['Neighbourhood'],
                                   latitudes=sac_data['Latitude'],
                                   longitudes=sac_data['Longitude']
                                  )
# Out:
# Downtown
# Old Sacramento
# East Sacramento
# Midtwon
# Cal Expo
# Oak Park
# Riverside
# Pocket
# Land Park
# Del Paso Heights
# Robla
# Southside Park
# Campus Commons
# South Natomas
# Strawberry Manor
# Natomas Crossing
# North Oak Park
# Tallac Village
# South Hagginwood
# Walsh Station
# Hagginwood
# Mansion Flats
# Mangan Park
# Old North Sacramento
# Poverty Ridge
# American River Parkway
# Fruitridge Manor
# Natomas Corporate Center
# Alhambra Triangle
# North City Farms
# Richmond Grove
# Z'berg Park
# RP Sports Complex
# Natomas Creek
# Golf Course Terrace
# Upper Land Park
# New Era Park
# Tahoe Park
# East Del Paso Heights
# Freeport Manor
# Erickson Industrial Park
# Tahoe Park South
# Dos Rios Triangle
# Norwood I-80
# Tahoe Park East
# Carleton Tract
# Colonial Village North
# South Land Park
# Creekside
# Westlake

# %%
print(sac_venues.shape)
sac_venues.head()
# Out:
# (551, 7)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>Neighbourhood Latitude</th>
#       <th>Neighbourhood Longitude</th>
#       <th>Venue</th>
#       <th>Venue Latitude</th>
#       <th>Venue Longitude</th>
#       <th>Venue Category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Downtown</td>
#       <td>38.581776</td>
#       <td>-121.511825</td>
#       <td>Raley Field</td>
#       <td>38.580010</td>
#       <td>-121.514293</td>
#       <td>Baseball Stadium</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Downtown</td>
#       <td>38.581776</td>
# ...

# %%
sac_venues.groupby('Neighbourhood').count()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood Latitude</th>
#       <th>Neighbourhood Longitude</th>
#       <th>Venue</th>
#       <th>Venue Latitude</th>
#       <th>Venue Longitude</th>
#       <th>Venue Category</th>
#     </tr>
#     <tr>
#       <th>Neighbourhood</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Alhambra Triangle</th>
#       <td>15</td>
#       <td>15</td>
#       <td>15</td>
#       <td>15</td>
#       <td>15</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>Cal Expo</th>
# ...

# %%
print('There are {} uniques categories.'.format(len(sac_venues['Venue Category'].unique())))
# Out:
# There are 158 uniques categories.

# %%
# one hot encoding
sac_onehot = pd.get_dummies(sac_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighbourhood column back to dataframe
sac_onehot['Neighbourhood'] = sac_venues['Neighbourhood'] 

# move neighbourhood column to the first column
fixed_columns = [sac_onehot.columns[-1]] + list(sac_onehot.columns[:-1])
sac_onehot = sac_onehot[fixed_columns]

sac_onehot.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
sac_onehot.shape
# Out:
# (551, 159)

# %%
sac_grouped = sac_onehot.groupby('Neighbourhood').mean().reset_index()
sac_grouped.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
num_top_venues = 5

for hood in sac_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = sac_grouped[sac_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alhambra Triangle----
#                   venue  freq
# 0         Grocery Store  0.13
# 1                   ATM  0.07
# 2       Thai Restaurant  0.07
# 3     Korean Restaurant  0.07
# 4  Fast Food Restaurant  0.07
#
#
# ----Cal Expo----
#              venue  freq
# 0       Bike Trail   0.5
# 1     Home Service   0.5
# 2     Optical Shop   0.0
# 3  Motorcycle Shop   0.0
# 4           Museum   0.0
#
#
# ----Campus Commons----
#               venue  freq
# 0            Lawyer  0.38
# 1       Bus Station  0.12
# 2    Sandwich Place  0.12
# 3        Taco Place  0.12
# 4  Business Service  0.12
#
#
# ----Carleton Tract----
#                 venue  freq
# 0  Seafood Restaurant  0.07
# 1           Pet Store  0.07
# 2         Coffee Shop  0.07
# 3  Salon / Barbershop  0.07
# 4    Sushi Restaurant  0.03
#
#
# ----Colonial Village North----
#              venue  freq
# 0     Intersection   1.0
# 1              ATM   0.0
# 2     Optical Shop   0.0
# 3  Motorcycle Shop   0.0
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = sac_grouped['Neighbourhood']

for ind in np.arange(sac_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sac_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>1st Most Common Venue</th>
#       <th>2nd Most Common Venue</th>
#       <th>3rd Most Common Venue</th>
#       <th>4th Most Common Venue</th>
#       <th>5th Most Common Venue</th>
#       <th>6th Most Common Venue</th>
#       <th>7th Most Common Venue</th>
#       <th>8th Most Common Venue</th>
#       <th>9th Most Common Venue</th>
#       <th>10th Most Common Venue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alhambra Triangle</td>
#       <td>Grocery Store</td>
#       <td>ATM</td>
#       <td>Bakery</td>
#       <td>Coffee Shop</td>
# ...

# %%
# Clustering Neighbourhoods

# set number of clusters
kclusters = 5

sac_grouped_clustering = sac_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sac_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:5]
# Out:
# array([0, 0, 0, 0, 1])

# %%
sac_merged = sac_grouped

# %%
# add clustering labels
sac_merged['Cluster Labels'] = kmeans.labels_

df3 = neighbourhoods_venues_sorted
# merge sac_grouped with sac_data to add latitude/longitude for each neighbourhood
sac_merged = sac_merged.join(df3.set_index('Neighbourhood'), on='Neighbourhood')
sac_merged = sac_merged.join(sac_venues.set_index('Neighbourhood'), on='Neighbourhood')
sac_merged.head()  # check the last columns!
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
# create map
map_clusters = folium.Map(location=[sac_latitude, sac_longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sac_merged['Venue Latitude'], sac_merged['Venue Longitude'], sac_merged['Neighbourhood'], sac_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters

# %%
# Cluster1

cluster1 = sac_merged.loc[sac_merged['Cluster Labels'] == 0] #, sac_merged.columns[[0] + list(range(5, sac_merged.shape[0]))]]
cluster1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
# Cluster2

cluster2 = sac_merged.loc[sac_merged['Cluster Labels'] == 1] #, sac_merged.columns[[0] + list(range(5, sac_merged.shape[0]))]]
cluster2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
# Cluster3

cluster3 = sac_merged.loc[sac_merged['Cluster Labels'] == 2] #, sac_merged.columns[[0] + list(range(5, sac_merged.shape[0]))]]
cluster3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
# Cluster4

cluster4 = sac_merged.loc[sac_merged['Cluster Labels'] == 3] #, sac_merged.columns[[0] + list(range(5, sac_merged.shape[0]))]]
cluster4
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
# Cluster5

cluster5 = sac_merged.loc[sac_merged['Cluster Labels'] == 4] #, sac_merged.columns[[0] + list(range(5, sac_merged.shape[0]))]]
cluster5
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>ATM</th>
#       <th>American Restaurant</th>
#       <th>Arcade</th>
#       <th>Art Gallery</th>
#       <th>Arts &amp; Crafts Store</th>
#       <th>Asian Restaurant</th>
#       <th>Athletics &amp; Sports</th>
#       <th>Auto Garage</th>
#       <th>Auto Workshop</th>
#       <th>BBQ Joint</th>
#       <th>Bakery</th>
#       <th>Bank</th>
#       <th>Bar</th>
#       <th>Baseball Field</th>
#       <th>Baseball Stadium</th>
#       <th>Beach</th>
#       <th>Beer Bar</th>
#       <th>Beer Garden</th>
#       <th>Big Box Store</th>
#       <th>Bike Rental / Bike Share</th>
# ...

# %%
print ("Neighbourhoods has more visitors to Restaurants are\n")
df4 = sac_merged[sac_merged['1st Most Common Venue'].str.contains('Restaurant')]
final_df = df4[['Neighbourhood', 'Neighbourhood Latitude', 'Neighbourhood Longitude','1st Most Common Venue']].copy()
final_df.drop_duplicates()
# Out:
# Neighbourhoods has more visitors to Restaurants are
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Neighbourhood</th>
#       <th>Neighbourhood Latitude</th>
#       <th>Neighbourhood Longitude</th>
#       <th>1st Most Common Venue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Carleton Tract</td>
#       <td>38.536156</td>
#       <td>-121.492918</td>
#       <td>Seafood Restaurant</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Dos Rios Triangle</td>
#       <td>38.593804</td>
#       <td>-121.486845</td>
#       <td>Mexican Restaurant</td>
#     </tr>
#     <tr>
#       <th>15</th>
# ...
